# %% [markdown]
# # Task4-Exploratory Data Analysis - Terrorism

# %% [markdown]
# # By-Janvi Gupta
# Data Science and Business Analytics Intern at The Spark Foundation

# %% [markdown]
# # Importing the libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt                       
import seaborn as sns

# %% [markdown]
# # Reading file

# %%
df = pd.read_excel(r'C:\Users\hp\Desktop\globalterrorismdb_0718dist.xlsx')
print("Data imported successfully")
df
# Out:
# Data imported successfully
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000000   1970       7     2        NaN         0        NaN
# 1       197000000000   1970       0     0        NaN         0        NaN
# 2       197000000000   1970       1     0        NaN         0        NaN
# 3       197000000000   1970       1     0        NaN         0        NaN
# 4       197000000000   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  202000000000   2017      12    31        NaN         0        NaN
# 181687  202000000000   2017      12    31        NaN         0        NaN
# 181688  202000000000   2017      12    31        NaN         0        NaN
# 181689  202000000000   2017      12    31        NaN         0        NaN
# 181690  202000000000   2017      12    31        NaN         0        NaN
#
# ...

# %% [markdown]
# # Dataset information

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.003238e+11    2002.638997       6.467277      15.505644
# std    1.383523e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.990000e+11    1991.000000       4.000000       8.000000
# 50%    2.010000e+11    2009.000000       6.000000      15.000000
# 75%    2.010000e+11    2014.000000       9.000000      23.000000
# max    2.020000e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
#copying the dataset into new dataframe
terr2=df.copy()
terr2.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000000   1970       7     2        NaN         0        NaN       58
# 1  197000000000   1970       0     0        NaN         0        NaN      130
# 2  197000000000   1970       1     0        NaN         0        NaN      160
# 3  197000000000   1970       1     0        NaN         0        NaN       78
# 4  197000000000   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
#Dropping null values       
terr2.dropna(axis=1,how='all')
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000000   1970       7     2        NaN         0        NaN
# 1       197000000000   1970       0     0        NaN         0        NaN
# 2       197000000000   1970       1     0        NaN         0        NaN
# 3       197000000000   1970       1     0        NaN         0        NaN
# 4       197000000000   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  202000000000   2017      12    31        NaN         0        NaN
# 181687  202000000000   2017      12    31        NaN         0        NaN
# 181688  202000000000   2017      12    31        NaN         0        NaN
# 181689  202000000000   2017      12    31        NaN         0        NaN
# 181690  202000000000   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
terr2.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'State','region_txt':'Region','target1':'Target','nkill':'Killed','nwound':'Wounded','gname':'Group','weaptype1_txt':'Weapon_type','targtype1_txt':'Target_type','attacktype1_txt':'AttackType','summary':'Summary','lattitude':'Lattitude','longitude':'Longitude','motive':'Motive'},inplace=True)

# %%
terr2=terr2[['Year','Month','Day','Country','State','Region','Longitude','AttackType','Wounded','Target','Summary','Group',
            'Target_type','Weapon_type','Motive']]
terr2['Wounded']=terr2['Wounded'].fillna(0).astype(int)

# %%
terr2['casuals']=terr2['Wounded']
terr2.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#     Longitude                      AttackType  Wounded  \
# 0  -69.951164                   Assassination        0
# 1  -99.086624     Hostage Taking (Kidnapping)        0
# 2  120.599741                   Assassination        0
# 3   23.762728               Bombing/Explosion        0
# 4  130.396361  Facility/Infrastructure Attack        0
#
#                     Target Summary                               Group  \
# 0             Julio Guzman     NaN                              MANO-D
# ...

# %%
terr2.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# State             421
# Region              0
# Longitude        4557
# AttackType          0
# Wounded             0
# Target            636
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# casuals             0
# dtype: int64

# %%
print('The country with highest terror attack:',terr2['Country'].value_counts().index[0])
print('Year with more attacks:',terr2['Year'].value_counts().index[0])
# Out:
# The country with highest terror attack: Iraq
# Year with more attacks: 2014

# %% [markdown]
# # Correlation

# %%
a = terr2.corr()
mask = np.triu(np.ones_like(a, dtype=bool))
c, ax = plt.subplots(figsize=(18,12))
cmap = sns.diverging_palette(250,20,as_cmap=True)
sns.heatmap(a, mask=mask, cmap=cmap, vmax=.3,center=0,square=True,linewidth=.5, cbar_kws={'shrink': .5})
plt.title("Corrilation matrix (data)")
# Out:
# Text(0.5, 1, 'Corrilation matrix (data)')

# %%
plt.figure(figsize=(15,15))
sns.heatmap(a,annot=True,annot_kws={'size':10},linewidth=1,vmin=0,vmax=0.5,cmap='ocean_r')
plt.title('correlayion matrix (data)')
plt.show()

# %% [markdown]
# # countries with most attacks

# %%
#top 10 countries with most attacks
print('countries with most attacks \n ' ,terr2['Country'].value_counts().head(10))
# Out:
# countries with most attacks
#   Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %% [markdown]
# # Visualization

# %%
plt.subplots(figsize=(20,20))
sns.barplot(terr2['Country'].value_counts()[:15].index,terr2['Country'].value_counts()[:15].values,palette='Greens_d')
plt.title('top countries affected')
plt.xlabel('countries')
plt.ylabel('counts')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # years with most attacks

# %%
print('Year with more attacks:',terr2['Year'].value_counts().idxmax())
# Out:
# Year with more attacks: 2014

# %%
plt.subplots(figsize=(20,20))
sns.barplot(terr2['Year'].value_counts().index,terr2['Year'].value_counts().values,palette='Greens_d')
plt.title('top countries affected')
plt.xlabel('year')
plt.ylabel('counts')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Region with most attacks

# %%
print('Regions with most attacks \n ' ,terr2['Region'].value_counts().head(10))
# Out:
# Regions with most attacks
#   Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Name: Region, dtype: int64

# %%
plt.subplots(figsize=(10,10))
sns.barplot(terr2['Region'].value_counts()[:15].index,terr2['Region'].value_counts()[:15].values)
plt.title('top Regions affected')
plt.xlabel('Regions')
plt.ylabel('counts')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # terror activities in each region through area plot

# %%
pd.crosstab(terr2.Year,terr2.Region).plot(kind='line',figsize=(10,10))
plt.title('Terrorist activities by each year')
plt.ylabel('number of attacks')
plt.show()

# %% [markdown]
# # Most attack Types

# %%
print('most attacks types : ',terr2['AttackType'].value_counts().idxmax())
# Out:
# most attacks types :  Bombing/Explosion

# %%
plt.subplots(figsize=(10,10))
sns.barplot(terr2['AttackType'].value_counts().index,terr2['AttackType'].value_counts().values)
plt.title('most Attacks Type')
plt.xlabel('Type')
plt.ylabel('counts')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# Country with most attacks = Iraq

# %% [markdown]
# Region with most attacks = Middle East and North Africa

# %% [markdown]
# Year with most attacks = 2014

# %% [markdown]
# most attacks Type = Bombing / Explosion

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Thank You!!
